# %%
import pandas as pd

# %%
wind_df = pd.read_csv('wind_dataset.csv')

# %%
wind_df
# Out:
#             DATE   WIND  IND  RAIN  IND.1  T.MAX  IND.2  T.MIN  T.MIN.G
# 0       1/1/1961  13.67    0   0.2    0.0    9.5    0.0    3.7     -1.0
# 1       1/2/1961  11.50    0   5.1    0.0    7.2    0.0    4.2      1.1
# 2       1/3/1961  11.25    0   0.4    0.0    5.5    0.0    0.5     -0.5
# 3       1/4/1961   8.63    0   0.2    0.0    5.6    0.0    0.4     -3.2
# 4       1/5/1961  11.92    0  10.4    0.0    7.2    1.0   -1.5     -7.5
# ...          ...    ...  ...   ...    ...    ...    ...    ...      ...
# 6569  12/27/1978  14.46    0  16.8    0.0    9.8    0.0    4.0      0.0
# 6570  12/28/1978  14.33    0  16.0    0.0    9.1    0.0    8.5      8.0
# 6571  12/29/1978  19.17    0  14.7    0.0    5.0    0.0    3.5      3.2
# 6572  12/30/1978  18.08    0   4.9    0.0    2.9    0.0    0.3     -0.5
# 6573  12/31/1978  19.25    0   0.5    0.0    1.2    1.0   -1.5     -3.0
#
# [6574 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os

# %%
wind_df['Year']=pd.DatetimeIndex(wind_df.DATE).year
wind_df['Month']=pd.DatetimeIndex(wind_df.DATE).month
wind_df['Day']=pd.DatetimeIndex(wind_df.DATE).day
wind_df['Weekday']=pd.DatetimeIndex(wind_df.DATE).weekday

# %%
wind_df
# Out:
#             DATE   WIND  IND  RAIN  IND.1  T.MAX  IND.2  T.MIN  T.MIN.G  Year  \
# 0       1/1/1961  13.67    0   0.2    0.0    9.5    0.0    3.7     -1.0  1961
# 1       1/2/1961  11.50    0   5.1    0.0    7.2    0.0    4.2      1.1  1961
# 2       1/3/1961  11.25    0   0.4    0.0    5.5    0.0    0.5     -0.5  1961
# 3       1/4/1961   8.63    0   0.2    0.0    5.6    0.0    0.4     -3.2  1961
# 4       1/5/1961  11.92    0  10.4    0.0    7.2    1.0   -1.5     -7.5  1961
# ...          ...    ...  ...   ...    ...    ...    ...    ...      ...   ...
# 6569  12/27/1978  14.46    0  16.8    0.0    9.8    0.0    4.0      0.0  1978
# 6570  12/28/1978  14.33    0  16.0    0.0    9.1    0.0    8.5      8.0  1978
# 6571  12/29/1978  19.17    0  14.7    0.0    5.0    0.0    3.5      3.2  1978
# 6572  12/30/1978  18.08    0   4.9    0.0    2.9    0.0    0.3     -0.5  1978
# 6573  12/31/1978  19.25    0   0.5    0.0    1.2    1.0   -1.5     -3.0  1978
#
#       Month  Day  Weekday
# ...

# %%
wind_df['IND.1']=wind_df['IND.1'].fillna(0)

# %%
print(wind_df.isnull().sum())
# Out:
# DATE         0
# WIND         0
# IND          0
# RAIN         0
# IND.1        0
# T.MAX      621
# IND.2       61
# T.MIN      674
# T.MIN.G    360
# Year         0
# Month        0
# Day          0
# Weekday      0
# dtype: int64

# %%
wind_df['T.MAX'].hist(figsize=[12,5])
# Out:
# <Axes: >
